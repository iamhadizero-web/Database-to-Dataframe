# %%
# Approach 2 
# RECOMMENDED 
# psycopg (v3) + SQLAlchemy 2.0

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine(
    "postgresql+psycopg://postgres:airbase234@localhost:5432/test"
)

# %%
df = pd.read_sql("SELECT * FROM product", engine)

# %%
print(df)
# Out:
#            name     category   price  quantity
# 0        Laptop  Electronics  1200.0        10
# 1    Smartphone  Electronics   800.0        20
# 2    Desk Chair    Furniture   150.0        15
# 3      Notebook   Stationery     5.5       100
# 4  Water Bottle      Kitchen    12.0        50
