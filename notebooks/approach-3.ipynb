# %%
# Approach 3 
# FASTEST 
# ADBC Driver (no SQLAlchemy)

# %%
import pandas as pd
import adbc_driver_postgresql.dbapi as pg

# %%
conn = pg.connect(
    "postgresql://postgres:airbase234@localhost:5432/test"
)

# %%
df = pd.read_sql("SELECT * FROM product", conn)

# %%
print(df)
# Out:
#            name     category    price  quantity
# 0        Laptop  Electronics  1200.00        10
# 1    Smartphone  Electronics   800.00        20
# 2    Desk Chair    Furniture   150.00        15
# 3      Notebook   Stationery     5.50       100
# 4  Water Bottle      Kitchen    12.00        50
